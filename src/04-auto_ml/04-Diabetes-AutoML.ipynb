# %% [markdown]
# # 04 - Training Models using Automated ML
#
# For this lab, we'll be using the AutoML UI in [AML Studio](https://ml.azure.com).
#
#
# You can, however, run AutoML via the SDK also. See [these sample notebooks](https://github.com/Azure/MachineLearningNotebooks/tree/master/how-to-use-azureml/automated-machine-learning) for examples.

# %% [markdown]
# [![](data:image/png;base64,...)](https://github.com/Azure/MachineLearningNotebooks/tree/master/how-to-use-azureml/automated-machine-learning)

# %% [markdown]
# <br><br><br><br><br>
#
#
#
#
#
#
# ###### Copyright (c) Microsoft Corporation. All rights reserved.
# ###### Licensed under the MIT License.
